# %% [markdown]
# <a href="https://colab.research.google.com/github/albanezgabriel008/Aulas-de-P.A/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entada

lado1 = 9
lado2 = 7

# %%
#processamento

area = lado1 * lado2

# %%
#saida

print(f"total da area calculada: {area} metros quadrados, sendo {lado1} de largura e {lado2} de comprimento")
# Out:
# total da area calculada: 63 metros quadrados, sendo 9 de largura e 7 de comprimento

# %% [markdown]
# operadores aritméticos
#
# 1.   soma = +
# 2.  subtração = -
# 3. multplicação = *
# 4. divisão = /

# %% [markdown]
# fazer um sistema que calcula a media aritmetica de um aluno e imprimi a media

# %%
#entrada
print('nome do aluno:')
nome = input()
print('nota 1:')
nota1 = float(input())
print('nota 2:')
nota2 = float(input())
print('nota 3:')
nota3 = float(input())
print('nota 4:')
nota4 = float(input())
# Out:
# nome do aluno:
# 7
# nota 1:
# 7
# nota 2:
# 7
# nota 3:
# 7
# nota 4:
# 7

# %%
#processamento
resultado = (float(nota1) + float(nota2) + float(nota3) + float(nota4)) /4

# %%
#saida
print(f"a nota do aluno {nome} é igual a {resultado}")
# Out:
# a nota do aluno 7 é igual a 7.0

# %% [markdown]
# dobro do numero

# %% [markdown]
# Faça um algoritmo q receba um numero e calcule o dobro dele

# %%
numero = float(33.5)

# %%
resultado = (numero) * 2

# %%
print(f'resultado: {resultado}')
# Out:
# resultado: 67.0
